# %%
# train_model.py
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.datasets import load_iris
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import joblib

# Load the Iris dataset
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

# One-hot encode the target variable
encoder = LabelBinarizer()
y_onehot = encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

# Define the neural network model
model = Sequential([
    Dense(10, input_shape=(4,), activation='relu'),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=4, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Model accuracy: {accuracy}")

# Save the trained model and the encoder
model.save('iris_nn_model.h5')
joblib.dump(encoder, 'label_encoder.pkl')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 4s 34ms/step - loss: 0.9525 - accuracy: 0.6583 - val_loss: 0.7751 - val_accuracy: 0.7000
# Epoch 2/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.7666 - accuracy: 0.6583 - val_loss: 0.6886 - val_accuracy: 0.7000
# Epoch 3/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.6853 - accuracy: 0.6667 - val_loss: 0.6339 - val_accuracy: 0.6667
# Epoch 4/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.6327 - accuracy: 0.6750 - val_loss: 0.5865 - val_accuracy: 0.7333
# Epoch 5/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.5846 - accuracy: 0.8083 - val_loss: 0.5501 - val_accuracy: 0.8000
# Epoch 6/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.5495 - accuracy: 0.7833 - val_loss: 0.5114 - val_accuracy: 0.8667
# Epoch 7/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.5141 - accuracy: 0.8500 - val_loss: 0.4916 - val_accuracy: 0.8000
# Epoch 8/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.4898 - accuracy: 0.8833 - val_loss: 0.4599 - val_accuracy: 0.8667
# Epoch 9/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.4677 - accuracy: 0.8500 - val_loss: 0.4417 - val_accuracy: 0.8333
# Epoch 10/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.4424 - accuracy: 0.8917 - val_loss: 0.4191 - val_accuracy: 0.8667
# Epoch 11/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.4222 - accuracy: 0.8833 - val_loss: 0.4014 - val_accuracy: 0.9333
# Epoch 12/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.4046 - accuracy: 0.9333 - val_loss: 0.3810 - val_accuracy: 0.8667
# Epoch 13/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3849 - accuracy: 0.9333 - val_loss: 0.3637 - val_accuracy: 0.8667
# Epoch 14/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3648 - accuracy: 0.9333 - val_loss: 0.3477 - val_accuracy: 0.9667
# Epoch 15/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3514 - accuracy: 0.9250 - val_loss: 0.3364 - val_accuracy: 0.9667
# Epoch 16/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3324 - accuracy: 0.9250 - val_loss: 0.3111 - val_accuracy: 0.9667
# Epoch 17/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3098 - accuracy: 0.9667 - val_loss: 0.2991 - val_accuracy: 0.9667
# Epoch 18/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2980 - accuracy: 0.9417 - val_loss: 0.2807 - val_accuracy: 1.0000
# Epoch 19/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2900 - accuracy: 0.9583 - val_loss: 0.2682 - val_accuracy: 1.0000
# Epoch 20/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2663 - accuracy: 0.9583 - val_loss: 0.2550 - val_accuracy: 1.0000
# Epoch 21/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2533 - accuracy: 0.9667 - val_loss: 0.2442 - val_accuracy: 0.9667
# Epoch 22/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2431 - accuracy: 0.9583 - val_loss: 0.2325 - val_accuracy: 1.0000
# Epoch 23/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2263 - accuracy: 0.9583 - val_loss: 0.2302 - val_accuracy: 0.9667
# Epoch 24/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2211 - accuracy: 0.9583 - val_loss: 0.2106 - val_accuracy: 1.0000
# Epoch 25/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2060 - accuracy: 0.9583 - val_loss: 0.2022 - val_accuracy: 1.0000
# Epoch 26/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2013 - accuracy: 0.9583 - val_loss: 0.2142 - val_accuracy: 0.9333
# Epoch 27/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1923 - accuracy: 0.9583 - val_loss: 0.1927 - val_accuracy: 0.9667
# Epoch 28/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1813 - accuracy: 0.9667 - val_loss: 0.1938 - val_accuracy: 0.9667
# Epoch 29/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1758 - accuracy: 0.9667 - val_loss: 0.1778 - val_accuracy: 0.9667
# Epoch 30/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1725 - accuracy: 0.9583 - val_loss: 0.1694 - val_accuracy: 1.0000
# Epoch 31/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1616 - accuracy: 0.9750 - val_loss: 0.1745 - val_accuracy: 0.9667
# Epoch 32/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1609 - accuracy: 0.9667 - val_loss: 0.1571 - val_accuracy: 1.0000
# Epoch 33/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1541 - accuracy: 0.9750 - val_loss: 0.1562 - val_accuracy: 1.0000
# Epoch 34/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1443 - accuracy: 0.9750 - val_loss: 0.1543 - val_accuracy: 0.9667
# Epoch 35/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1426 - accuracy: 0.9583 - val_loss: 0.1434 - val_accuracy: 1.0000
# Epoch 36/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1377 - accuracy: 0.9667 - val_loss: 0.1547 - val_accuracy: 0.9667
# Epoch 37/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1343 - accuracy: 0.9667 - val_loss: 0.1353 - val_accuracy: 1.0000
# Epoch 38/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1275 - accuracy: 0.9667 - val_loss: 0.1302 - val_accuracy: 1.0000
# Epoch 39/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1325 - accuracy: 0.9750 - val_loss: 0.1391 - val_accuracy: 0.9667
# Epoch 40/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1259 - accuracy: 0.9667 - val_loss: 0.1331 - val_accuracy: 1.0000
# Epoch 41/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1193 - accuracy: 0.9667 - val_loss: 0.1233 - val_accuracy: 1.0000
# Epoch 42/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1298 - accuracy: 0.9667 - val_loss: 0.1307 - val_accuracy: 1.0000
# Epoch 43/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1177 - accuracy: 0.9583 - val_loss: 0.1287 - val_accuracy: 1.0000
# Epoch 44/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1131 - accuracy: 0.9667 - val_loss: 0.1218 - val_accuracy: 1.0000
# Epoch 45/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1115 - accuracy: 0.9750 - val_loss: 0.1131 - val_accuracy: 1.0000
# Epoch 46/50
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1203 - accuracy: 0.9583 - val_loss: 0.1078 - val_accuracy: 1.0000
# Epoch 47/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1070 - accuracy: 0.9750 - val_loss: 0.1230 - val_accuracy: 1.0000
# Epoch 48/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1023 - accuracy: 0.9833 - val_loss: 0.1037 - val_accuracy: 1.0000
# Epoch 49/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1073 - accuracy: 0.9667 - val_loss: 0.1320 - val_accuracy: 0.9000
# Epoch 50/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1012 - accuracy: 0.9833 - val_loss: 0.1019 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1019 - accuracy: 1.0000
# Model accuracy: 1.0
# C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ['label_encoder.pkl']
